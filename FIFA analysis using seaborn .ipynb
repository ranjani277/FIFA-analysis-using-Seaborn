# %% [markdown]
# #  Advance seaborn visualization

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from collections import Counter    # Counter class is a subclass of the dictionary that can be used to count the frequency of items in an iterable, such as a list, a tuple, or a string.

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import os
for dirname,_,filenames  in os.walk("D:/October/17-10-23/Seaborn/"):
    for filename in filenames:
        print('File location : ', os.path.join(dirname,filename))
# Out:
# File location :  D:/October/17-10-23/Seaborn/FIFA.csv
# File location :  D:/October/17-10-23/Seaborn/seaborn-tutorial-for-beginners.ipynb

# %%
fifa19=pd.read_csv(r"D:/October/17-10-23/Seaborn/FIFA.csv",index_col=0) # not cosider the column 0

# %%
fifa19.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
fifa19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18207 entries, 0 to 18206
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Special                   18207 non-null  int64
# ...

# %%
sns.set_style('darkgrid')

# %%
# the above summaration categorical attribute =45,numerical (int=5,float=38)

# %%
f,ax =plt.subplots(figsize=(8,6))
x=fifa19['Age']
vis1=sns.distplot(x,bins=10)
plt.show()

# %%
f,ax =plt.subplots(figsize=(8,6))
x=fifa19['Age']
x=pd.Series(x,name='Age variable')
vis1=sns.distplot(x,bins=10)
plt.show()

# %%
f,ax =plt.subplots(figsize=(8,6))
x=fifa19['Age']
vis1=sns.distplot(x,bins=10,vertical=True)
plt.show()

# %%
f,ax =plt.subplots(figsize=(8,6))
x=fifa19['Age']
x=pd.Series(x,name="Age variable")
vis2=sns.kdeplot(x)
plt.show()

# %%
f,ax =plt.subplots(figsize=(8,6))
x=fifa19['Age']
x=pd.Series(x,name="Age variable")
vis2=sns.kdeplot(x,shade=True,color='red')
plt.show()

# %%
f,ax =plt.subplots(figsize=(8,6))
x=fifa19['Age']
vis3=sns.distplot(x,kde=False,rug=True,bins=10)
plt.show()

# %%
f,ax =plt.subplots(figsize=(8,6))
x=fifa19['Age']
vis2=sns.distplot(x,hist=False,bins=10,rug=True)
plt.show()

# %%
fifa19['Preferred Foot'].nunique()
# Out:
# 2

# %%
# Preferred foot is cateorical attribute
fifa19['Preferred Foot'].unique()
# Out:
# array(['Left', 'Right', nan], dtype=object)

# %%
fifa19['Preferred Foot'].value_counts()
# Out:
# Right    13948
# Left      4211
# Name: Preferred Foot, dtype: int64

# %%
f,ax= plt.subplots(figsize=(8,6))
vis4= sns.countplot(x= 'Preferred Foot',data=fifa19,palette=('blue','orange'))
plt.show()

# %%
f,ax= plt.subplots(figsize=(8,6))
vis4= sns.countplot(x= 'Preferred Foot',data=fifa19,hue='Real Face')
plt.show()

# %%
f,ax= plt.subplots(figsize=(8,6))
vis4= sns.countplot(y= 'Preferred Foot',data=fifa19,hue='Real Face')
plt.show()

# %%
vis4= sns.catplot(x= 'Preferred Foot',data=fifa19,kind='count')
plt.show()

# %%
fifa19['International Reputation'].nunique()
# Out:
# 5

# %%
fifa19['International Reputation'].value_counts()
# Out:
# 1.0    16532
# 2.0     1261
# 3.0      309
# 4.0       51
# 5.0        6
# Name: International Reputation, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="International Reputation", y="Potential", data=fifa19)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="International Reputation", y="Potential", data=fifa19,jitter=0.01,palette=('red','yellow','green','orange','pink'))
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="International Reputation", y="Potential", data=fifa19,hue='Preferred Foot',palette='Set2',jitter=0.2,dodge=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="International Reputation", y="Potential", hue="Preferred Foot", 
                   data=fifa19, palette="Set2", size=20, marker="D",
                   edgecolor="gray", alpha=.25)
plt.show()

# %%
sns.boxplot(x='Potential',data=fifa19)
# Out:
# <Axes: xlabel='Potential'>

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="International Reputation", y="Potential", data=fifa19,palette='Set2')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="International Reputation", y="Potential", hue="Preferred Foot", data=fifa19, palette="Set2")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot( x="Potential", data=fifa19,palette='Set2')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot( x= 'International Reputation',y="Potential", data=fifa19,palette='Set2')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot( x='International Reputation',y="Potential", hue='Preferred Foot',data=fifa19,palette='muted',split=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", data=fifa19)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential",hue='Preferred Foot',data=fifa19)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", hue='Preferred Foot',data=fifa19,
                 marker=['o','x'],linestyles=['-','--'],dodge=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa19,palette='Set3')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa19,hue='Preferred Foot')
plt.show()

# %%
from numpy import median
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa19, estimator=median,palette='Set3')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa19, ci=68,palette='Set2')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa19, ci='sd',palette='Set2')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x="International Reputation", y="Potential", data=fifa19, capsize=0.2,palette='Set2')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x="Overall", y="Potential", data=fifa19)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x="Overall", y="Potential", data=fifa19,marker='+',color='red')
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.regplot(x="International Reputation", y="Potential", data=fifa19,x_jitter=0.01)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(x="Height", y="Weight", data=fifa19)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.lineplot(x="Stamina", y="Strength", data=fifa19)
plt.show()

# %%
vis4=sns.lmplot(x='Overall',y='Potential',data=fifa19)

# %%
vis4=sns.lmplot(x='Overall',y='Potential',data=fifa19,hue='Preferred Foot')

# %%
vis4=sns.lmplot(x='Overall',y='Potential',data=fifa19,hue='Preferred Foot',palette='Set2')

# %%
vis4=sns.lmplot(x='Overall',y='Potential',data=fifa19,col='Preferred Foot',palette='Set2')

# %%
g=sns.FacetGrid(fifa19,col='Preferred Foot')  # catergorical attribute Facetgrid

# %%
g=sns.FacetGrid(fifa19,col='Preferred Foot')
g=g.map(plt.hist,'Potential')

# %%
g=sns.FacetGrid(fifa19,col='Preferred Foot')
g=(g.map(plt.scatter,'Height','Weight',edgecolor='w')).add_legend()

# %%
fifa19_new = fifa19[['Age', 'Potential', 'Strength', 'Stamina', 'Preferred Foot']]

# %%
plt.figure(figsize=(6,4))
g = sns.PairGrid(fifa19_new)
g = g.map(plt.scatter)

# %%
sns.pairplot(fifa19_new,kind='scatter')

# %%
g = sns.PairGrid(fifa19_new)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
g = sns.PairGrid(fifa19_new,hue='Preferred Foot')
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
g = sns.PairGrid(fifa19_new, hue="Preferred Foot")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
g = sns.PairGrid(fifa19_new, vars=['Age', 'Stamina'])
g = g.map(plt.scatter)

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa19)
g = g.plot(sns.regplot, sns.distplot)

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa19)
g = g.plot_joint(sns.scatterplot,color='0.5',edgecolor='white')
g=g.plot_marginals(sns.distplot,kde=False,color='0.5')

# %%
g = sns.JointGrid(x="Overall", y="Potential", data=fifa19, space=0)
g = g.plot_joint(sns.kdeplot, cmap="Blues_d")
g = g.plot_marginals(sns.kdeplot, shade=True)

# %%
g = sns.PairGrid(fifa19_new)
g = g.map_upper(plt.scatter)
g = g.map_lower(sns.kdeplot, cmap="Blues_d")
g = g.map_diag(sns.kdeplot, lw=3, legend=True)

# %%
def sinplot(flip=1):
    x=np.linspace(0,14,100)
    for i in range(1,6):
        plt.plot(x,np.sin(x+i*.5)*(7-i)*flip)

# %%
sinplot()

# %%
sns.set()
sinplot()

# %%
sns.set_style('whitegrid')
sinplot()

# %%
sns.set_style('dark')
sinplot()

# %%
sns.set_style('white')
sinplot()

# %%
sns.set_style('ticks')
sinplot()
